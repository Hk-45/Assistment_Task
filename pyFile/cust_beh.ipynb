# %%
import pandas as pd
import seaborn as sb

customerBehavior = pd.read_csv("D:/Data-Analyst9/SQL/assistment/customer_behavior.csv", header=0, index_col=0)

customerBehavior
# Out:
#                    Region  SatisfactionScore  PurchaseFrequency  AverageSpend  \
# CustomerID
# b92aa407      Middle East                  8               5.95        362.86
# f82f37ec      Middle East                  4              14.42        401.32
# 36ee83b4    North America                  1               3.39        425.86
# 8f7a7b0c    North America                  7              10.37        123.00
# d86f9336             APAC                  5               2.56         40.65
# ...                   ...                ...                ...           ...
# 293fd95f             APAC                  4              15.31        364.16
# 8bbd7388             APAC                  9               7.67        320.67
# b56c3dc0           Europe                  5               7.80        468.90
# b55c4745           Europe                  6              18.16        280.42
# ca2f1173      Middle East                  3              15.03        408.93
#
#            ChurnRisk  ReferralCount
# CustomerID
# b92aa407         Low             10
# f82f37ec        High              3
# 36ee83b4         Low              1
# 8f7a7b0c         Low              4
# d86f9336         Low              6
# ...              ...            ...
# 293fd95f      Medium              9
# 8bbd7388        High              4
# b56c3dc0      Medium              2
# b55c4745        High              6
# ca2f1173        High              5
#
# [1000 rows x 6 columns]

# %%
sb.barplot(data= customerBehavior)
# Out:
# <Axes: >
